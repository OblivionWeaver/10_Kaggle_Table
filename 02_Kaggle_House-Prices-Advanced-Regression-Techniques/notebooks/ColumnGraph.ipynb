# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
submission = pd.read_csv('./data/sample_submission.csv')

# %%
df = pd.concat([train,test],ignore_index=True,sort=False)
# df.info()

# %%
sns.jointplot(train.MSSubClass,train.SalePrice)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(train.LotArea,train.SalePrice)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train['LotShape'].replace(['Reg','IR1','IR2','IR3'],[0,1,2,3],inplace=True)
sns.jointplot(train.LotShape,train.SalePrice)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(train.Street,train.SalePrice)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train['Alley'].value_counts()
# Out:
# Grvl    50
# Pave    41
# Name: Alley, dtype: int64

# %%
train['LandContour'].replace(['Lvl','Bnk','HLS','Low'],[0,1,2,3],inplace=True)
sns.jointplot(train.LandContour,train.SalePrice)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train['Condition1'].value_counts()
# Out:
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64

# %%
sns.jointplot(train.OverallQual,train.SalePrice)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train['GrLivArea'].value_counts()
# Out:
# 864     22
# 1040    14
# 894     11
# 848     10
# 1456    10
#         ..
# 3447     1
# 1396     1
# 1395     1
# 1393     1
# 2054     1
# Name: GrLivArea, Length: 861, dtype: int64

# %%
sns.jointplot(train.GarageArea,train.SalePrice)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
train['Fireplaces'].value_counts()
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
sns.distplot(train.YearRemodAdd)
# Out:
# C:\Users\yusuk\anaconda3\envs\AI_Learning\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearRemodAdd', ylabel='Density'>

# %%
train['Exterior1st'].value_counts()
# Out:
# VinylSd    515
# HdBoard    222
# MetalSd    220
# Wd Sdng    206
# Plywood    108
# CemntBd     61
# BrkFace     50
# WdShing     26
# Stucco      25
# AsbShng     20
# BrkComm      2
# Stone        2
# ImStucc      1
# AsphShn      1
# CBlock       1
# Name: Exterior1st, dtype: int64

# %%
Tier3 = ['MSSubClass','MSZoning','LotArea','LandContour','LotConfig',
         'Neighborhood','Condition1','Condition2','BldgType','HouseStyle',
         'OverallQual','YearBuilt','YearRemodAdd','Exterior1st','Foundation',
         'TotalBsmtSF','1stFlrSF','2ndFlrSF','GrLivArea','TotRmsAbvGrd',
         'GarageArea','WoodDeckSF','OpenPorchSF','SaleType','SaleCondition']

# %%
Tier2 = ['MSSubClass','MSZoning','LotArea','LandContour','Neighborhood',
        'Condition1','Condition2','HouseStyle','OverallQual','YearBuilt',
        'YearRemodAdd','Exterior1st','TotalBsmtSF','1stFlrSF','2ndFlrSF',
        'GrLivArea','TotRmsAbvGrd','SaleType','SaleCondition']
